# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import boto3

# %%
dbfs_path = 'dbfs:/FileStore/tables/trail_Ontario.csv'
local_path = 'file:///tmp/trail_Ontario.csv'
dbutils.fs.cp(dbfs_path, local_path)

# %%
data_path = "/tmp/trail_Ontario.csv"
with open(data_path, 'r') as f:
  reader = csv.reader(f, delimiter=',')
  # get header from first row
  headers = next(reader)
  # get all the rows as a list
  data = list(reader)
  # transform data into numpy array
  data = np.array(data).astype(float)
    
print(headers)
print(data.shape)
print(data[:3])

# %%
# Plot the data
plt.plot(data[:, 1], data[:, 0])
plt.axis('equal')
plt.xlabel(headers[1])
plt.ylabel(headers[0])
plt.show()

plt.plot(data[:, 2])
plt.xlabel('Table Index')
plt.ylabel(headers[2])
plt.show()

# %%
# Read Data using numpy library in Python

# %%
types = ['f8', 'f8', 'i4']
# i4 - 32-bit signed integer
# f8 - 64-bit floating-point number
data = np.genfromtxt(data_path, dtype=types, delimiter=',',names=True)

# %%
print(data)

# %%
plt.plot(data['Longitude'], data['Latitude'])
plt.axis('equal')
plt.show()
plt.show()

# %%
# Read Data using Pandas library in Python

# %%
df = pd.read_csv(data_path)
df.head()

# %%
plt.plot(data['Longitude'], data['Latitude'])
plt.axis('equal')
plt.show()
plt.show()

# %%
df.max()

# %%
df['Elevation'].max()

# %%
df[df.Elevation == 503.0]

# %%
df[df.Elevation == df['Elevation'].max()]
